# %%
import time 
import psutil
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation 
from matplotlib import style

# %matplotlib notebook
plt.rcParams['animation.html'] = 'jshtml'

#Clear text file
'''file = open("text.txt","r+")
file.truncate(0)
file.close()'''

#Real time Plot
plt.style.use('ggplot')
fig = plt.figure(figsize=(6,8))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
while True:   
    
    reward = []
    data = open("Plot_model_1.txt", "r").read()
    line = data.split('\n')[:-1]
    x = np.arange(1,len(line)+1)

    for i in range(0, len(line)):
        if len(line) >= 1:
            reward.append(float(line[i]))

    average_reward = np.cumsum(reward)/x
    
    ax1.plot(x, reward, color='b', linewidth=1)
    ax1.title.set_text('Reward')
    
    ax2.plot(x, average_reward, color='b', linewidth=1)
    ax2.title.set_text('Average Reward')
    
    fig.canvas.draw()
    
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-415a75e0bb17> in <module>
#      18     ax2.title.set_text('Average Reward')
#      19
# ---> 20     fig.canvas.draw()
#      21
#      22     time.sleep(5)
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py in draw(self)
#     150         self._png_is_old = True
#     151         try:
# --> 152             super().draw()
#     153         finally:
#     154             self.manager.refresh_all()  # Swap the frames.
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
# ...
